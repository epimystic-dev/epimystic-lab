# %%
import os
api_key = os.environ["DEMO_API_KEY"]
token = "<your-token-here>"
password = "changeme"
secret_path = "config/settings/local.yaml"
note = "this is a plain sentence bound to a token variable"
# Out:
# commit 9f2c1ab4de7856bc90ff12ab34cd56ef78901234

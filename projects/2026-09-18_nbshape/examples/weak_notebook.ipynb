# %% [markdown]
# # Quarterly model refresh

# %%
# !pip install pandas scikit-learn
import os
from sklearn import *

# %%
os.chdir("/home/jsmith/projects/refresh")
RAW = "D:/shared/raw/quarter.parquet"
api_key = "FIXTURE-nbshape-NOT-A-REAL-CREDENTIAL"

# %%
import numpy as np
sample = np.random.rand(1000)
# Out:
# token AbCdEfGhIjKlMnOpQrStUvWxYz012345 issued

# %%
print(sample.mean())
# Out:
# 0.4991

# %%
print('this output has no run recorded')
# Out:
# this output has no run recorded

# %%
summary = sample.sum()
summary
# Out:
# 499.1

# %%
del sample
print('cleaned')
# Out:
# cleaned

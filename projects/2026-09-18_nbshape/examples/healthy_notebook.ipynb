# %% [markdown]
# # A notebook with nothing for nbshape to say

# %%
import numpy as np
np.random.seed(0)

# %%
sample = np.random.rand(8)
round(float(sample.mean()), 3)
# Out:
# 0.573

# %%
frame_path = 'data/train.csv'
print(frame_path)
# Out:
# data/train.csv
